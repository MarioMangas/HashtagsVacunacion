# %% [markdown]
# ## Cómo se han comportado los 100 hashtags más twiteados a los largo de la semana

# %%
plt.figure(figsize=(10,7))
for i in range(10):
    plt.plot(df[df['Texto'].str.contains(lista_hashtag[i])].resample('H', on='Fecha')['Nombre'].count().index,
        df[df['Texto'].str.contains(lista_hashtag[i])].resample('H', on='Fecha')['Nombre'].count().values, label=str(i)+ ' ' + lista_hashtag[i])
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.figure(figsize=(10,7))
for i in range(10,20):
    plt.plot(df[df['Texto'].str.contains(lista_hashtag[i])].resample('H', on='Fecha')['Nombre'].count().index,
        df[df['Texto'].str.contains(lista_hashtag[i])].resample('H', on='Fecha')['Nombre'].count().values, label=str(i)+ ' ' + lista_hashtag[i])
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.figure(figsize=(10,7))
for i in range(20,30):
    plt.plot(df[df['Texto'].str.contains(lista_hashtag[i])].resample('H', on='Fecha')['Nombre'].count().index,
        df[df['Texto'].str.contains(lista_hashtag[i])].resample('H', on='Fecha')['Nombre'].count().values, label=str(i)+ ' ' + lista_hashtag[i])
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.figure(figsize=(10,7))
for i in range(30,40):
    plt.plot(df[df['Texto'].str.contains(lista_hashtag[i])].resample('H', on='Fecha')['Nombre'].count().index,
        df[df['Texto'].str.contains(lista_hashtag[i])].resample('H', on='Fecha')['Nombre'].count().values, label=str(i)+ ' ' + lista_hashtag[i])
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.figure(figsize=(10,7))
for i in range(40,50):
    plt.plot(df[df['Texto'].str.contains(lista_hashtag[i])].resample('H', on='Fecha')['Nombre'].count().index,
        df[df['Texto'].str.contains(lista_hashtag[i])].resample('H', on='Fecha')['Nombre'].count().values, label=str(i)+ ' ' + lista_hashtag[i])
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.figure(figsize=(10,7))
for i in range(50,60):
    plt.plot(df[df['Texto'].str.contains(lista_hashtag[i])].resample('H', on='Fecha')['Nombre'].count().index,
        df[df['Texto'].str.contains(lista_hashtag[i])].resample('H', on='Fecha')['Nombre'].count().values, label=str(i)+ ' ' + lista_hashtag[i])
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.figure(figsize=(10,7))
for i in range(60,70):
    plt.plot(df[df['Texto'].str.contains(lista_hashtag[i])].resample('H', on='Fecha')['Nombre'].count().index,
        df[df['Texto'].str.contains(lista_hashtag[i])].resample('H', on='Fecha')['Nombre'].count().values, label=str(i)+ ' ' + lista_hashtag[i])
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.figure(figsize=(10,7))
for i in range(70,80):
    plt.plot(df[df['Texto'].str.contains(lista_hashtag[i])].resample('H', on='Fecha')['Nombre'].count().index,
        df[df['Texto'].str.contains(lista_hashtag[i])].resample('H', on='Fecha')['Nombre'].count().values, label=str(i)+ ' ' + lista_hashtag[i])
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.figure(figsize=(10,7))
for i in range(80,90):
    plt.plot(df[df['Texto'].str.contains(lista_hashtag[i])].resample('H', on='Fecha')['Nombre'].count().index,
        df[df['Texto'].str.contains(lista_hashtag[i])].resample('H', on='Fecha')['Nombre'].count().values, label=str(i)+ ' ' + lista_hashtag[i])
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.figure(figsize=(10,7))
for i in range(90,100):
    plt.plot(df[df['Texto'].str.contains(lista_hashtag[i])].resample('H', on='Fecha')['Nombre'].count().index,
        df[df['Texto'].str.contains(lista_hashtag[i])].resample('H', on='Fecha')['Nombre'].count().values, label=str(i)+ ' ' + lista_hashtag[i])
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="1000">
